# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv("HYDRUS_outputs/A_level.txt", delim_whitespace=True)
# Out:
# /var/folders/sr/b1jfzfhx2njdgxj7lvjsvstm0000gn/T/ipykernel_4455/1957194341.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   raw_data = pd.read_csv("HYDRUS_outputs/A_level.txt", delim_whitespace=True)

# %%
raw_data.head()
# Out:
#       Time  sum(rTop)  sum(rRoot)     sum(vTop)  sum(vRoot)     sum(vBot)  \
# 0  0.08333        0.0         0.0  9.030000e-14         0.0  0.000000e+00
# 1  0.16667        0.0         0.0  4.220000e-12         0.0  3.220000e-09
# 2  0.25000        0.0         0.0  1.410000e-11         0.0 -9.240000e-08
# 3  0.33333        0.0         0.0  8.220000e-12         0.0  2.460000e-06
# 4  0.41667        0.0         0.0  2.010000e-11         0.0 -6.740000e-05
#
#     hTop  hRoot  hBot  A-level
# 0 -100.0  -74.8   0.0        1
# 1 -100.0  -74.8   0.0        2
# 2 -100.0  -74.8   0.0        3
# 3 -100.0  -74.8   0.0        4
# 4 -100.0  -74.8   0.0        5

# %%
for item in raw_data.columns:
    print(item)
# Out:
# Time
# sum(rTop)
# sum(rRoot)
# sum(vTop)
# sum(vRoot)
# sum(vBot)
# hTop
# hRoot
# hBot
# A-level

# %%
plt.plot(raw_data['sum(rTop)'])

# %%
plt.plot(raw_data['sum(rRoot)'])

# %%
plt.plot(raw_data['sum(vTop)'])

# %%
plt.plot(raw_data['sum(vRoot)'])

# %%
plt.plot(raw_data['sum(vBot)'])

# %%
plt.plot(raw_data['hTop'])

# %%
plt.plot(raw_data['hRoot'])

# %%
plt.plot(raw_data['hBot'])

# %%
plt.plot(raw_data['sum(vTop)'])

# %%
plt.plot(raw_data['sum(rTop)'])

# %%
plt.plot(raw_data['sum(vTop)'] - raw_data['sum(rTop)'] )
